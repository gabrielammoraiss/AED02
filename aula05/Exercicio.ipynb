# %% [markdown]
# Crie uma classe Pessoa com nome e idade. Adicione método faz_aniversario() que incrementa a idade em 1. Use __srt__() para retornar algo como" <nome>, <idade> anos". Crie duas pessoas e mostre a idade de cada uma antes de chamar faz aniverssário

# %%
class Pessoa:
    def __init__(nome, idade):
        self.__nome = nome
        self.__idade = idade

    def faz_aniverssario(self):
        self.__idade += 1

    def __str__(self):
        return f' {self.__nome} tem {sel.__idade} anos Km/h'
